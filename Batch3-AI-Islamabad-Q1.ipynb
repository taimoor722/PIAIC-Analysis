# 1699               Ubaid  Wahab Khan  PIAIC75214             1
# 1700                     Israr Ahmad  PIAIC75300             1
# 1701                     Abdul Salar  PIAIC75258             1
# 1702                       Majid Ali  PIAIC66963             1
# 1703            Muhammad Ahsan Iqbal  PIAIC65990             1
# 1704                     Badar Ahmed  PIAIC72244             1
# 1705                    Haseeb Ahmed  PIAIC56725             1
# 1706                    Abdur Rehman  PIAIC74483             1
# 1707        Raja Muhammad Adeel Zauq  PIAIC67344             1
# 1708                     Adrish Baig  PIAIC73272             1
# 1709                    Shahid Ameen  PIAIC75632             1
# 1710                Muhammad Shakeel  PIAIC54564             1
# 1711              Yusra Abdul Qayyum  PIAIC78235             1
#
#       Overall Percentile  Rank
# 0                    100     1
# 1                    100     1
# 2                    100     1
# 3                    100     1
# 4                    100     1
# 5                    100     1
# 6                    100     1
# 7                     99     8
# 8                     99     8
# 9                     99     8
# 10                    99     8
# 11                    99     8
# 12                    99     8
# 13                    99     8
# 14                    99     8
# 15                    99     8
# 16                    99     8
# 17                    99     8
# 18                    99     8
# 19                    99     8
# 20                    99     8
# 21                    98    22
# 22                    98    22
# 23                    98    22
# 24                    98    22
# 25                    98    22
# 26                    98    22
# 27                    98    22
# 28                    98    22
# 29                    98    22
# ...                  ...   ...
# 1682                   0  1315
# 1683                   0  1315
# 1684                   0  1315
# 1685                   0  1315
# 1686                   0  1315
# 1687                   0  1315
# 1688                   0  1315
# 1689                   0  1315
# 1690                   0  1315
# 1691                   0  1315
# 1692                   0  1315
# 1693                   0  1315
# 1694                   0  1315
# 1695                   0  1315
# 1696                   0  1315
# 1697                   0  1315
# 1698                   0  1315
# 1699                   0  1315
# 1700                   0  1315
# 1701                   0  1315
# 1702                   0  1315
# 1703                   0  1315
# 1704                   0  1315
# 1705                   0  1315
# 1706                   0  1315
# 1707                   0  1315
# 1708                   0  1315
# 1709                   0  1315
# 1710                   0  1315
# 1711                   0  1315
#
# [1712 rows x 5 columns]

# %%
freq_q1=q1['Overall Percentile']
freq_q1
# Out:
# 0       100
# 1       100
# 2       100
# 3       100
# 4       100
# 5       100
# 6       100
# 7        99
# 8        99
# 9        99
# 10       99
# 11       99
# 12       99
# 13       99
# 14       99
# 15       99
# 16       99
# 17       99
# 18       99
# 19       99
# 20       99
# 21       98
# 22       98
# 23       98
# 24       98
# 25       98
# 26       98
# 27       98
# 28       98
# 29       98
#        ...
# 1682      0
# 1683      0
# 1684      0
# 1685      0
# 1686      0
# 1687      0
# 1688      0
# 1689      0
# 1690      0
# 1691      0
# 1692      0
# 1693      0
# 1694      0
# 1695      0
# 1696      0
# 1697      0
# 1698      0
# 1699      0
# 1700      0
# 1701      0
# 1702      0
# 1703      0
# 1704      0
# 1705      0
# 1706      0
# 1707      0
# 1708      0
# 1709      0
# 1710      0
# 1711      0
# Name: Overall Percentile, Length: 1712, dtype: int32

# %%
percentage_attemed=round(((q1['Tests Missed'] == 0).value_counts()/q1.notnull().sum()[0])*100,2)

# %%
percentage_attemed.plot(kind='pie',labels=['attemped','Missed'],)
plt.title('Attempt vs Missed')
# Out:
# Text(0.5, 1.0, 'Attempt vs Missed')

# %%
plt.figure(figsize=(7,7))
plt.pie(percentage_attemed,labels=['Attempted','Missed'],labeldistance=0.35,autopct='%.0f%%',
       shadow=True, startangle= -90, 
        textprops={'fontsize': 18},
       explode=(0.1,0.1),colors=['c','pink'],)
        
plt.title('AI For Every one- Q1',fontsize=20,color='black')
# Out:
# Text(0.5, 1.0, 'AI For Every one- Q1')

# %%
percentile_attempted=freq_q1[freq_q1 != 0]
len(percentile_attempted.value_counts())
pectile_bined=percentile_attempted.value_counts(bins=2)
pec=pectile_bined.values
student_grouping=pd.DataFrame(pec,columns=['no_of_student'])
# student_grouping['group']=['scored less than 40','scored between 60-80','scored above 80','scored bewteen 40-60']
# student_grouping.sort_values('no_of_student',inplace=True)


student_grouping['group']=['  60','scored above 60']
student_grouping.sort_values('no_of_student',inplace=True)
student_grouping
pectile_bined
# Out:
# (22.921999999999997, 61.5]    659
# (61.5, 100.0]                 655
# Name: Overall Percentile, dtype: int64

# %%
fig1=plt.figure(figsize=(15,8),facecolor="#ffff99")
ax1=fig1.add_subplot(111)
col="""Name
Roll Number
Tests Missed
Overall Percentile
Rank""".split('\n')
# ax1.hist(percentile_attempted,bins=10,histtype='stepfilled',alpha=0.4)
# ax1.bar(x=np.arange(35)+0.75,height=percentile_attempted.value_counts())
ax1.pie(student_grouping['no_of_student'],
        #autopct='%.1f%% \n students',
       autopct=lambda p: '{:.0f}\n students'.format(p * pectile_bined.sum() / 100),
        labels=student_grouping["group"],
       labeldistance=1.1,
       shadow=True, startangle= -210, 
        textprops={'fontsize': 18},
       explode=(0.09,0.09),colors=['c','pink'],
        rotatelabels =False,
        counterclock=False
       )
plt.title('Batch-3 Performance -AI Quiz')
plt.text(0.1, 0.9,'Analysis \nOn Q1', ha='center', va='center', transform=ax1.transAxes)
# Out:
# Text(0.1, 0.9, 'Analysis \nOn Q1')

# %%
fig2=plt.figure(figsize=(7,7))
ax2=fig2.add_subplot(111)
ax2.hist(freq_q1[freq_q1 != 0],range(20,101,40))
# Out:
# (array([659., 655.]), array([ 20,  60, 100]), <a list of 2 Patch objects>)

# %%
q1.loc[q1['Overall Percentile'] != 0,'Overall Percentile'].describe(percentiles=[.80,.50,.90])
#this show only 20% students score above 82 score


# almmost 52% students fail to score  60 points (those who attempted ) which is 300 students
# Out:
# count    1314.000000
# mean       60.374429
# std        22.122380
# min        23.000000
# 50%        58.000000
# 80%        82.000000
# 90%        92.000000
# max       100.000000
# Name: Overall Percentile, dtype: float64
